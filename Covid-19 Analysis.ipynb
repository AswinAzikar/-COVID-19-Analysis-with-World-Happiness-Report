# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sb 
import pandas as pd

# %%
covid_conf = pd.read_csv(  '/kaggle/input/covid-19-analysis-data/covid19_Confirmed_dataset.csv' )

# %%
covid_conf.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
covid_conf.shape
# Out:
# (266, 104)

# %%
covid_conf.drop(["Lat","Long","Province/State" ],axis=1,inplace=True)

#
# This Python code is used to remove the "Lat" and "Long" columns from a Pandas DataFrame called "covid_conf":

# covid_conf.drop(...): This part calls the drop() method on the DataFrame covid_conf. The drop() method is used to remove rows or columns from a DataFrame.
# ["Lat", "Long"]: This is a list containing the names of the columns you want to remove. In this case, you're removing the columns labeled "Lat" and "Long".
# axis=1: This argument specifies that you want to drop columns. If you set axis=0, you would be dropping rows instead.
# inplace=True: This argument tells the drop() method to modify the DataFrame directly. If you set inplace=False, the drop() method would return a new DataFrame with the columns removed, leaving the original DataFrame unchanged.
# So, in essence, this code removes the latitude and longitude columns from the "covid_conf" DataFrame, modifying the DataFrame directly.

# %%
covid_conf.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0     1463     1531     1703     1828     1939     2171
# ...

# %%
agg_df = covid_conf.groupby("Country/Region").sum()

# %%
agg_df.shape
# Out:
# (187, 100)

# %%
#Data viz  resepected to countries



# The respective row contains non numeric objects, hence converted to number values then 
china_data = agg_df.loc["China"]
china_data.plot()


afgan_data = agg_df.loc["Afghanistan"]
afgan_data.plot()
india_data = agg_df.loc["India"]
india_data.plot()
spain_data = agg_df.loc["Spain"]
spain_data.plot()


plt.legend()

# %%
agg_df.isnull()
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan           False    False    False    False    False    False
# Albania               False    False    False    False    False    False
# Algeria               False    False    False    False    False    False
# Andorra               False    False    False    False    False    False
# Angola                False    False    False    False    False    False
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza    False    False    False    False    False    False
# Western Sahara        False    False    False    False    False    False
# Yemen                 False    False    False    False    False    False
# Zambia                False    False    False    False    False    False
# Zimbabwe              False    False    False    False    False    False
#
# ...

# %%
china_data[:3].plot()
# Out:
# <Axes: >

# %%
#calulating the first derivative
china_data.diff().plot()
india_data.diff().plot()
afgan_data.diff().plot()
spain_data.diff().plot()

plt.legend()

# %%
china_data.diff().max()
# Out:
# 15136.0

# %%
india_data.diff().max()
# Out:
# 1893.0

# %%
afgan_data.diff().max()
# Out:
# 232.0

# %%
spain_data.diff().max()
# Out:
# 9630.0

# %%
#Add a col to show max infect rates among all the countries

countries = list(agg_df.index)
max_inf_rates = []
for c in countries : 
    max_inf_rates.append(agg_df.loc[c].diff().max())
    
agg_df["max_infected_rate"] = max_inf_rates

# %%
agg_df.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
# new df

co_data = pd.DataFrame(agg_df["max_infected_rate"] )
co_data
# Out:
#                     max_infected_rate
# Country/Region
# Afghanistan                     232.0
# Albania                          34.0
# Algeria                         199.0
# Andorra                          43.0
# Angola                            5.0
# ...                               ...
# West Bank and Gaza               66.0
# Western Sahara                    4.0
# Yemen                             5.0
# Zambia                            9.0
# Zimbabwe                          8.0
#
# [187 rows x 1 columns]

# %%
hap_rep = pd.read_csv("/kaggle/input/covid-19-analysis-data/worldwide_happiness_report.csv")

# %%
hap_rep
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
hap_rep.drop(["Overall rank", "Score", "Generosity","Perceptions of corruption" ],axis=1, inplace = True )

# %%
hap_rep
# Out:
#             Country or region  GDP per capita  Social support  \
# 0                     Finland           1.340           1.587
# 1                     Denmark           1.383           1.573
# 2                      Norway           1.488           1.582
# 3                     Iceland           1.380           1.624
# 4                 Netherlands           1.396           1.522
# ..                        ...             ...             ...
# 151                    Rwanda           0.359           0.711
# 152                  Tanzania           0.476           0.885
# 153               Afghanistan           0.350           0.517
# 154  Central African Republic           0.026           0.000
# 155               South Sudan           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices
# 0                      0.986                         0.596
# 1                      0.996                         0.592
# ...

# %%
hap_rep.set_index('Country or region', inplace = True)

# %%
hap_rep.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
co_data.shape
# Out:
# (187, 1)

# %%
hap_rep.shape
# Out:
# (156, 4)

# %%
joined_df = co_data.join(hap_rep,how="inner")

# %%
joined_df
# Out:
#              max_infected_rate  GDP per capita  Social support  \
# Afghanistan              232.0           0.350           0.517
# Albania                   34.0           0.947           0.848
# Algeria                  199.0           1.002           1.160
# Argentina                291.0           1.092           1.432
# Armenia                  134.0           0.850           1.055
# ...                        ...             ...             ...
# Venezuela                 29.0           0.960           1.427
# Vietnam                   19.0           0.741           1.346
# Yemen                      5.0           0.287           1.163
# Zambia                     9.0           0.578           1.058
# Zimbabwe                   8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# ...

# %%
joined_df.corr()
# Out:
#                               max_infected_rate  GDP per capita  \
# max_infected_rate                      1.000000        0.250118
# GDP per capita                         0.250118        1.000000
# Social support                         0.191958        0.759468
# Healthy life expectancy                0.289263        0.863062
# Freedom to make life choices           0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infected_rate                   0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infected_rate                                 0.078196
# ...

# %%
sb.heatmap(joined_df.corr(),annot=True, cmap="RdYlGn", fmt=".2f", linewidths=0.5)
# Out:
# <Axes: >

# %%
x = joined_df["GDP per capita"]
y = joined_df["max_infected_rate"]

plt.figure(figsize=(10, 6))
sb.scatterplot(x=x, y=np.log(y), color="blue", marker="o")

plt.xlabel("GDP per Capita")
plt.ylabel("Log of Max Infected Rate")
plt.title("Scatterplot of GDP per Capita vs Log of Max Infected Rate")
plt.grid(True) 
plt.tight_layout()
plt.show()

# %%
x = joined_df["GDP per capita"]
y = joined_df["max_infected_rate"]

# Plotting
plt.figure(figsize=(10, 6))
sb.regplot(x=x, y=np.log(y), color="blue", marker="o")

# Adding labels and title
plt.xlabel("GDP per Capita")
plt.ylabel("Log of Max Infected Rate")
plt.title("Regressed Scatterplot of GDP per Capita vs Log of Max Infected Rate")
plt.grid(True)  # Optional for better visualization
plt.tight_layout()
plt.show()

# %%
x = joined_df["Social support"]
y = joined_df["max_infected_rate"]


plt.figure(figsize=(10, 6))
sb.scatterplot(x=x, y=np.log(y), color="green", marker="o")


plt.xlabel("Social support")
plt.ylabel("Log of Max Infected Rate")
plt.title("Scatterplot of Social support vs Log of Max Infected Rate")
plt.grid(True)  
plt.tight_layout()
plt.show()

# %%
x = joined_df["Social support"]
y = joined_df["max_infected_rate"]


plt.figure(figsize=(10, 6))
sb.regplot(x=x, y=np.log(y), color="green", marker="o")


plt.xlabel("Social support")
plt.ylabel("Log of Max Infected Rate")
plt.title("Regrresed Scatter plot of Social support vs Log of Max Infected Rate")
plt.grid(True)  
plt.tight_layout()
plt.show()

# %%
x = joined_df["Healthy life expectancy"]
y = joined_df["max_infected_rate"]


plt.figure(figsize=(10, 6))
sb.scatterplot(x=x, y=np.log(y), color="brown", marker="o")


plt.xlabel("Healthy life expectancy")
plt.ylabel("Log of Max Infected Rate")
plt.title(" Scatter plot of Healthy life expectancy vs Log of Max Infected Rate")
plt.grid(True)  
plt.tight_layout()
plt.show()

# %%
x = joined_df["Healthy life expectancy"]
y = joined_df["max_infected_rate"]


plt.figure(figsize=(10, 6))
sb.regplot(x=x, y=np.log(y), color="brown", marker="o")


plt.xlabel("Healthy life expectancy")
plt.ylabel("Log of Max Infected Rate")
plt.title(" Regressed Scatter plot of Healthy life expectancy vs Log of Max Infected Rate")
plt.grid(True)  
plt.tight_layout()
plt.show()

# %%
x = joined_df["Freedom to make life choices"]
y = joined_df["max_infected_rate"]


plt.figure(figsize=(10, 6))
sb.scatterplot(x=x, y=np.log(y), color="blue", marker="2")


plt.xlabel("Freedom to make life choices")
plt.ylabel("Log of Max Infected Rate")
plt.title(" Scatter plot of Freedom to make life choices vs Log of Max Infected Rate")
plt.grid(True)  
plt.tight_layout()
plt.show()

# %%
x = joined_df["Freedom to make life choices"]
y = joined_df["max_infected_rate"]


plt.figure(figsize=(10, 6))
sb.regplot(x=x, y=np.log(y), color="blue", marker="2")


plt.xlabel("Freedom to make life choices")
plt.ylabel("Log of Max Infected Rate")
plt.title(" Scatter plot of Freedom to make life choices vs Log of Max Infected Rate")
plt.grid(True)  
plt.tight_layout()
plt.show()
